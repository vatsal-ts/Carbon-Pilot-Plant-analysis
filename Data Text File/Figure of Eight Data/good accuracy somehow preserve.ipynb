# %%
import numpy as np
from numpy import loadtxt
from statistics import stdev
import matplotlib.pyplot as plt
import pprint
import pandas as pd
from pprint import pprint
import tensorflow as tf
import seaborn as sns
from sklearn.model_selection import train_test_split
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score

# %%
BigX=loadtxt("stripper_train_3.txt")
BigX1b=BigX
# for i in range(2,14):
#     next=loadtxt("stripper_data_"+str(i)+"b.txt")
#     BigX=np.concatenate((BigX,next),axis=0)

#BigX1b=np.concatenate((BigX1b,BigX2b),axis=0)
#print(BigX)
#print(type(BigX))
dim=len(BigX[0]) #number of cols
num_examples_train=len(BigX)
print(dim,num_examples_train)

# dim2b=len(BigX2b[0]) #number of cols
# num_examples_train2b=len(BigX2b)
# print(dim2b,num_examples_train2b)
# TestX=loadtxt("process_data_testing.txt")
# num_examples_test=len(TestX)
#print(dim,num_examples_test)
BigX_org=BigX
# Out:
# 76 348

# %%
# def normaliser(genericData):
#     #normalising
#     min_indices=np.amin(genericData,axis=0)
#     #print(min_indices)
#     max_indices=np.amax(genericData,axis=0)
#     #print(max_indices)
#     diff_train=max_indices-min_indices
#     #print(diff_train)
#     check=(genericData-min_indices)/diff_train
#     #print(check)
#     data_normalised= tf.cast(check, tf.float32)
#     #print(train_data_normalised)
#     #print(type(train_data_normalised))
#     return data_normalised

'''
I will try to scale in a robust fashion since data may contain plenty of anomalies
https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html#sklearn.preprocessing.RobustScaler
https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html
'''
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %%
# transformerRS = RobustScaler().fit(BigX)
# transformerRS.transform(BigX)
scaling = RobustScaler()
BigX=scaling.fit_transform(BigX)
#RobustScaler(quantile_range=(25, 75)).fit_transform(BigX)
pprint(BigX)
pprint(BigX_org)
if(np.array_equal(BigX_org, BigX)):
    print("robust scaler not useful")
# Out:
# array([[ 1.41605446, -1.52249757,  0.        , ..., -1.07643041,
#         -1.10439255, -1.04277602],
#        [ 1.45585832, -1.38803624,  0.        , ..., -1.1057564 ,
#         -1.05601046, -1.03773527],
#        [ 1.44342859, -1.47518155,  0.        , ..., -1.09845247,
#         -1.05398156, -0.99002406],
#        ...,
#        [-0.29838521,  0.92296174,  0.        , ...,  0.92425672,
#          0.90920571,  0.93713135],
#        [-0.27345392,  0.89780639,  0.        , ...,  0.93890276,
#          0.95054558,  0.93731169],
#        [-0.25556374,  0.92745377,  0.        , ...,  0.91997701,
#          0.9365285 ,  0.94034669]])
# array([[1.1028586e+01, 8.3787500e-01, 1.2360000e-02, ..., 1.9439188e+01,
#         1.9453783e+01, 2.0169388e+01],
#        [1.1029140e+01, 8.3832400e-01, 1.2360000e-02, ..., 1.9432274e+01,
#         1.9465277e+01, 2.0170534e+01],
#        [1.1028967e+01, 8.3803300e-01, 1.2360000e-02, ..., 1.9433996e+01,
#         1.9465759e+01, 2.0181381e+01],
#        ...,
#        [1.1004724e+01, 8.4604100e-01, 1.2360000e-02, ..., 1.9910877e+01,
#         1.9932148e+01, 2.0619514e+01],
#        [1.1005071e+01, 8.4595700e-01, 1.2360000e-02, ..., 1.9914330e+01,
#         1.9941969e+01, 2.0619555e+01],
#        [1.1005320e+01, 8.4605600e-01, 1.2360000e-02, ..., 1.9909868e+01,
#         1.9938639e+01, 2.0620245e+01]])

# %%
# print(train_data_normalised)
#setting up parameters for autoencoder
nb_epoch = 2000
batch_size = 32
input_dim = dim #num of columns,6
#encoding_dim = 60
hidden_dim_1 = 65
hidden_dim_2= 55
bottleneck = 40
learning_rate = 1e-10
print("{:.15f}".format(learning_rate))
# Out:
# 0.000000000100000

# %%
#input Layer
input_layer = tf.keras.layers.Input(shape=(input_dim, ))

# %%
# #Encoder
# encoder = tf.keras.layers.Dense(encoding_dim, activation="tanh",activity_regularizer=tf.keras.regularizers.l2(learning_rate))(input_layer)
# #encoder=tf.keras.layers.Dropout(0.2)(encoder)
# encoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)

#encoder = tf.keras.layers.Dense(encoding_dim, activation="relu")(input_layer)
encoder=tf.keras.layers.Dense(hidden_dim_1,activation="relu")(input_layer)
encoder=tf.keras.layers.Dropout(0.2)(encoder)
encoder=tf.keras.layers.Dense(hidden_dim_2,activation="relu")(encoder)
encoder= tf.keras.layers.Dense(bottleneck,activation="relu")(encoder)
# # encoder=  tf.keras.layers.Dropout(0.2)(encoder)
# encoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
# encoder = tf.keras.layers.Dense(hidden_dim_2, activation="relu")(encoder)

# %%
# # Decoder
# # decoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
# # decoder=tf.keras.layers.Dropout(0.2)(decoder)
# decoder = tf.keras.layers.Dense(encoding_dim, activation='relu')(encoder)
# decoder = tf.keras.layers.Dense(input_dim, activation='tanh')(decoder)

# decoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
# #decoder=tf.keras.layers.Dropout(0.2)(decoder)
# decoder = tf.keras.layers.Dense(encoding_dim, activation="relu")(decoder)
# decoder = tf.keras.layers.Dense(input_dim, activation="relu")(decoder)
decoder=tf.keras.layers.Dense(hidden_dim_2,activation="relu")(encoder)
decoder=tf.keras.layers.Dropout(0.2)(decoder)
decoder=tf.keras.layers.Dense(hidden_dim_1,activation="relu")(decoder)
#decoder=tf.keras.layers.Dense(encoding_dim,activation="relu")(decoder)
decoder=tf.keras.layers.Dense(input_dim,activation="relu")(decoder)
# justcheck=tf.keras.layers.Dense(6,activation="relu")(input_layer)

# %%
#Autoencoder
autoencoder = tf.keras.Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 76)]              0
# _________________________________________________________________
# dense (Dense)                (None, 65)                5005
# _________________________________________________________________
# dropout (Dropout)            (None, 65)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 55)                3630
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                2240
# _________________________________________________________________
# dense_3 (Dense)              (None, 55)                2255
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 55)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 65)                3640
# _________________________________________________________________
# dense_5 (Dense)              (None, 76)                5016
# =================================================================
# Total params: 21,786
# Trainable params: 21,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # callbacks for checkpoints and early stopping
# cp = tf.keras.callbacks.ModelCheckpoint(filepath="autoencoder_fraud.h5",
#                                mode='min', monitor='val_loss', verbose=2, save_best_only=True)
# # define our early stopping
# early_stop = tf.keras.callbacks.EarlyStopping(
#     monitor='val_loss',
#     min_delta=0.0001,
#     patience=10,
#     verbose=1, 
#     mode='min',
#     restore_best_weights=True
#     )

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

# %%
history = autoencoder.fit(BigX, BigX,
                    epochs=nb_epoch,
                    shuffle=True,
                    ).history
# Out:
# Epoch 1/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.4261 - accuracy: 0.0565
# Epoch 2/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.3498 - accuracy: 0.0314
# Epoch 3/2000
# 11/11 [==============================] - 0s 604us/step - loss: 0.3439 - accuracy: 0.0158
# Epoch 4/2000
# 11/11 [==============================] - 0s 834us/step - loss: 0.3184 - accuracy: 0.0447
# Epoch 5/2000
# 11/11 [==============================] - 0s 957us/step - loss: 0.3136 - accuracy: 0.1155
# Epoch 6/2000
# 11/11 [==============================] - 0s 892us/step - loss: 0.3128 - accuracy: 0.1953
# Epoch 7/2000
# 11/11 [==============================] - 0s 861us/step - loss: 0.2798 - accuracy: 0.2368
# Epoch 8/2000
# 11/11 [==============================] - 0s 957us/step - loss: 0.2852 - accuracy: 0.2366
# Epoch 9/2000
# 11/11 [==============================] - 0s 946us/step - loss: 0.2767 - accuracy: 0.2478
# Epoch 10/2000
# 11/11 [==============================] - 0s 904us/step - loss: 0.2787 - accuracy: 0.2615
# Epoch 11/2000
# 11/11 [==============================] - 0s 956us/step - loss: 0.2940 - accuracy: 0.2438
# Epoch 12/2000
# 11/11 [==============================] - 0s 943us/step - loss: 0.2930 - accuracy: 0.2817
# Epoch 13/2000
# 11/11 [==============================] - 0s 862us/step - loss: 0.2748 - accuracy: 0.2919
# Epoch 14/2000
# 11/11 [==============================] - 0s 965us/step - loss: 0.2828 - accuracy: 0.3728
# Epoch 15/2000
# 11/11 [==============================] - 0s 894us/step - loss: 0.2761 - accuracy: 0.3980
# Epoch 16/2000
# 11/11 [==============================] - 0s 418us/step - loss: 0.2974 - accuracy: 0.4589
# Epoch 17/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2675 - accuracy: 0.3869
# Epoch 18/2000
# 11/11 [==============================] - 0s 477us/step - loss: 0.2417 - accuracy: 0.3751
# Epoch 19/2000
# 11/11 [==============================] - 0s 434us/step - loss: 0.2635 - accuracy: 0.4527
# Epoch 20/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.
2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2400 - accuracy: 0.6282
# Epoch 68/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2351 - accuracy: 0.6298
# Epoch 69/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2393 - accuracy: 0.6176
# Epoch 70/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2418 - accuracy: 0.6387
# Epoch 71/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2392 - accuracy: 0.6186
# Epoch 72/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2281 - accuracy: 0.6510
# Epoch 73/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2254 - accuracy: 0.6718
# Epoch 74/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2346 - accuracy: 0.6233
# Epoch 75/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2445 - accuracy: 0.7196
# Epoch 76/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2325 - accuracy: 0.6390
# Epoch 77/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2469 - accuracy: 0.6421
# Epoch 78/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2477 - accuracy: 0.7105
# Epoch 79/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2466 - accuracy: 0.6430
# Epoch 80/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2547 - accuracy: 0.6569
# Epoch 81/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2424 - accuracy: 0.7069
# Epoch 82/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2432 - accuracy: 0.7145
# Epoch 83/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2409 - accuracy: 0.6978
# Epoch 84/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2312 - accuracy: 0.7174
# Epoch 85/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2437 - accuracy: 0.6676
# Epoch 86/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2459 - accuracy: 0.6898
# Epoch 87/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2570 - accuracy: 0.7773
# Epoch 88/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2415 - accuracy: 0.6960
# Epoch 89/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2362 - accuracy: 0.6736
# Epoch 90/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2532 - accuracy: 0.7120
# Epoch 91/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2314 - accuracy: 0.7328
# Epoch 92/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2436 - accuracy: 0.6841
# Epoch 93/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2312 - accuracy: 0.7277
# Epoch 94/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2293 - accuracy: 0.7198
# Epoch 95/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2379 - accuracy: 0.6970
# Epoch 96/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2352 - accuracy: 0.7344
# Epoch 97/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2427 - accuracy: 0.7748
# Epoch 98/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2372 - accuracy: 0.6522
# Epoch 99/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2432 - accuracy: 0.7353
# Epoch 100/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2422 - accuracy: 0.6636
# Epoch 101/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2343 - accuracy: 0.7135
# Epoch 102/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2261 - accuracy: 0.7065
# Epoch 103/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2440 - accuracy: 0.7197
# Epoch 104/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2378 - accuracy: 0.6971
# Epoch 105/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2439 - accuracy: 0.7553
# Epoch 106/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2437 - accuracy: 0.7428
# Epoch 107/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2435 - accuracy: 0.6853
# Epoch 108/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2459 - accuracy: 0.6957
# Epoch 109/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2291 - accuracy: 0.7429
# Epoch 110/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2417 - accuracy: 0.7289
# Epoch 111/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2456 - accuracy: 0.7538
# Epoch 112/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2148 - accuracy: 0.7077
# Epoch 113/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2446 - accuracy: 0.7559
# Epoch 114/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2303 - accuracy: 0.7096
# Epoch 115/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2518 - accuracy: 0.6833
# Epoch 116/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2468 - accuracy: 0.7330
# Epoch 117/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2221 - accuracy: 0.7176
# Epoch 118/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2488 - accuracy: 0.7467
# Epoch 119/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2465 - accuracy: 0.6724
# Epoch 120/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2365 - accuracy: 0.7348
# Epoch 121/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2318 - accuracy: 0.7308
# Epoch 122/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2496 - accuracy: 0.7050
# Epoch 123/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2408 - accuracy: 0.6945
# Epoch 124/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2293 - accuracy: 0.7340
# Epoch 125/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2501 - accuracy: 0.7634
# Epoch 126/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2619 - accuracy: 0.7372
# Epoch 127/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2443 - accuracy: 0.7324
# Epoch 128/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2394 - accuracy: 0.7650
# Epoch 129/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2280 - accuracy: 0.7002
# Epoch 130/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2153 - accuracy: 0.7322
# Epoch 131/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2374 - accuracy: 0.7480
# Epoch 132/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2371 - accuracy: 0.7433
# Epoch 133/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2382 - accuracy: 0.7104
# Epoch 134/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2412 - accuracy: 0.7472
# Epoch 135/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2446 - accuracy: 0.7619
# Epoch 136/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2148 - accuracy: 0.7283
# Epoch 137/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2300 - accuracy: 0.7097
# Epoch 138/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2265 - accuracy: 0.7651
# Epoch 139/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2364 - accuracy: 0.7091
# Epoch 140/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2438 - accuracy: 0.7723
# Epoch 141/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2430 - accuracy: 0.7747
# Epoch 142/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2413 - accuracy: 0.7711
# Epoch 143/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2361 - accuracy: 0.7259
# Epoch 144/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2368 - accuracy: 0.7389
# Epoch 145/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2333 - accuracy: 0.7729
# Epoch 146/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2337 - accuracy: 0.7309
# Epoch 147/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2407 - accuracy: 0.7511
# Epoch 148/2000
# 11/11 [==============================] - 0s 796us/step - loss: 0.2194 - accuracy: 0.7078
# Epoch 149/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2291 - accuracy: 0.7861
# Epoch 150/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2423 - accuracy: 0.7478
# Epoch 151/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2304 - accuracy: 0.7904
# Epoch 152/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2279 - accuracy: 0.7471
# Epoch 153/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2397 - accuracy: 0.8207
# Epoch 154/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2381 - accuracy: 0.8075
# Epoch 155/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2230 - accuracy: 0.7935
# Epoch 156/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2235 - accuracy: 0.7643
# Epoch 157/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2368 - accuracy: 0.7784
# Epoch 158/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2402 - accuracy: 0.7703
# Epoch 159/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2242 - accuracy: 0.8071
# Epoch 160/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2120 - accuracy: 0.6882
# Epoch 161/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2309 - accuracy: 0.7508
# Epoch 162/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2494 - accuracy: 0.7494
# Epoch 163/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2329 - accuracy: 0.7809
# Epoch 164/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2406 - accuracy: 0.7419
# Epoch 165/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2265 - accuracy: 0.7732
# Epoch 166/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2314 - accuracy: 0.7649
# Epoch 167/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2480 - accuracy: 0.7490
# Epoch 168/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2396 - accuracy: 0.7179
# Epoch 169/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2329 - accuracy: 0.7524
# Epoch 170/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2514 - accuracy: 0.7554
# Epoch 171/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2274 - accuracy: 0.7614
# Epoch 172/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2530 - accuracy: 0.7815
# Epoch 173/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2474 - accuracy: 0.7526
# Epoch 174/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.7697
# Epoch 175/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.7663
# Epoch 176/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2366 - accuracy: 0.7468
# Epoch 177/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2372 - accuracy: 0.7945
# Epoch 178/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.7931
# Epoch 179/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2476 - accuracy: 0.7777
# Epoch 180/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2340 - accuracy: 0.7805
# Epoch 181/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2247 - accuracy: 0.7795
# Epoch 182/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2414 - accuracy: 0.7690
# Epoch 183/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2336 - accuracy: 0.7834
# Epoch 184/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2291 - accuracy: 0.7713
# Epoch 185/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2369 - accuracy: 0.7677
# Epoch 186/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2323 - accuracy: 0.7583
# Epoch 187/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.8052
# Epoch 188/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2313 - accuracy: 0.7562
# Epoch 189/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2309 - accuracy: 0.7730
# Epoch 190/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.7942
# Epoch 191/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.7395
# Epoch 192/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2302 - accuracy: 0.7701
# Epoch 193/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2273 - accuracy: 0.7476
# Epoch 194/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2293 - accuracy: 0.7856
# Epoch 195/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2304 - accuracy: 0.7982
# Epoch 196/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2263 - accuracy: 0.7782
# Epoch 197/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2393 - accuracy: 0.7337
# Epoch 198/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2231 - accuracy: 0.7750
# Epoch 199/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2193 - accuracy: 0.8134
# Epoch 200/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.7585
# Epoch 201/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2306 - accuracy: 0.7716
# Epoch 202/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2298 - accuracy: 0.7811
# Epoch 203/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2353 - accuracy: 0.7880
# Epoch 204/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.7975
# Epoch 205/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2566 - accuracy: 0.8026
# Epoch 206/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.7432
# Epoch 207/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2405 - accuracy: 0.7847
# Epoch 208/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2397 - accuracy: 0.7995
# Epoch 209/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2410 - accuracy: 0.8089
# Epoch 210/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2357 - accuracy: 0.7624
# Epoch 211/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2245 - accuracy: 0.8295
# Epoch 212/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.8086
# Epoch 213/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2340 - accuracy: 0.8166
# Epoch 214/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2329 - accuracy: 0.7433
# Epoch 215/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2309 - accuracy: 0.7799
# Epoch 216/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2355 - accuracy: 0.8204
# Epoch 217/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2383 - accuracy: 0.7677
# Epoch 218/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2265 - accuracy: 0.7943
# Epoch 219/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2427 - accuracy: 0.7966
# Epoch 220/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.7766
# Epoch 221/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2368 - accuracy: 0.7739
# Epoch 222/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2595 - accuracy: 0.7677
# Epoch 223/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2220 - accuracy: 0.7341
# Epoch 224/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2457 - accuracy: 0.7856
# Epoch 225/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2483 - accuracy: 0.7806
# Epoch 226/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2366 - accuracy: 0.8096
# Epoch 227/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2290 - accuracy: 0.7984
# Epoch 228/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2234 - accuracy: 0.7884
# Epoch 229/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2341 - accuracy: 0.7668
# Epoch 230/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.7883
# Epoch 231/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2330 - accuracy: 0.7504
# Epoch 232/2000
# 11/11 [==============================] - 0s 897us/step - loss: 0.2380 - accuracy: 0.7735
# Epoch 233/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2258 - accuracy: 0.7723
# Epoch 234/2000
# 11/11 [==============================] - 0s 897us/step - loss: 0.2329 - accuracy: 0.7805
# Epoch 235/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2017 - accuracy: 0.8271
# Epoch 236/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2381 - accuracy: 0.7867
# Epoch 237/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2396 - accuracy: 0.7486
# Epoch 238/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.8021
# Epoch 239/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.8142
# Epoch 240/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2173 - accuracy: 0.7742
# Epoch 241/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.7986
# Epoch 242/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2159 - accuracy: 0.7634
# Epoch 243/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2236 - accuracy: 0.7743
# Epoch 244/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2564 - accuracy: 0.7470
# Epoch 245/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2356 - accuracy: 0.7729
# Epoch 246/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2209 - accuracy: 0.7982
# Epoch 247/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2338 - accuracy: 0.7707
# Epoch 248/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2355 - accuracy: 0.7511
# Epoch 249/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2251 - accuracy: 0.7487
# Epoch 250/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2444 - accuracy: 0.7763
# Epoch 251/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2295 - accuracy: 0.7930
# Epoch 252/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2328 - accuracy: 0.7880
# Epoch 253/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2223 - accuracy: 0.7880
# Epoch 254/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.7994
# Epoch 255/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.7751
# Epoch 256/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2217 - accuracy: 0.8094
# Epoch 257/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.7751
# Epoch 258/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2232 - accuracy: 0.8005
# Epoch 259/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.8082
# Epoch 260/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2306 - accuracy: 0.7802
# Epoch 261/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2270 - accuracy: 0.7584
# Epoch 262/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2291 - accuracy: 0.7740
# Epoch 263/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2509 - accuracy: 0.7626
# Epoch 264/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2311 - accuracy: 0.8064
# Epoch 265/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2368 - accuracy: 0.8217
# Epoch 266/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2245 - accuracy: 0.7553
# Epoch 267/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2206 - accuracy: 0.8278
# Epoch 268/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.8244
# Epoch 269/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2405 - accuracy: 0.8160
# Epoch 270/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2249 - accuracy: 0.7871
# Epoch 271/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2279 - accuracy: 0.7868
# Epoch 272/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2305 - accuracy: 0.8000
# Epoch 273/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2311 - accuracy: 0.7767
# Epoch 274/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2446 - accuracy: 0.7534
# Epoch 275/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2216 - accuracy: 0.8116
# Epoch 276/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.7880
# Epoch 277/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2303 - accuracy: 0.8010
# Epoch 278/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.8180
# Epoch 279/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2380 - accuracy: 0.7878
# Epoch 280/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2510 - accuracy: 0.7346
# Epoch 281/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2495 - accuracy: 0.8264
# Epoch 282/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2239 - accuracy: 0.7629
# Epoch 283/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.7967
# Epoch 284/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.7491
# Epoch 285/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2305 - accuracy: 0.8137
# Epoch 286/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2362 - accuracy: 0.7958
# Epoch 287/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2287 - accuracy: 0.8135
# Epoch 288/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.7825
# Epoch 289/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2160 - accuracy: 0.8223
# Epoch 290/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2410 - accuracy: 0.8007
# Epoch 291/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2327 - accuracy: 0.8466
# Epoch 292/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2243 - accuracy: 0.7880
# Epoch 293/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2184 - accuracy: 0.7872
# Epoch 294/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.7722
# Epoch 295/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2262 - accuracy: 0.7666
# Epoch 296/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2283 - accuracy: 0.8197
# Epoch 297/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2266 - accuracy: 0.8041
# Epoch 298/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2246 - accuracy: 0.7910
# Epoch 299/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.7798
# Epoch 300/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2047 - accuracy: 0.8113
# Epoch 301/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2045 - accuracy: 0.7601
# Epoch 302/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2229 - accuracy: 0.7616
# Epoch 303/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.7832
# Epoch 304/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2326 - accuracy: 0.8442
# Epoch 305/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 0.8020
# Epoch 306/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.7688
# Epoch 307/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2321 - accuracy: 0.7945
# Epoch 308/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2357 - accuracy: 0.7971
# Epoch 309/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2334 - accuracy: 0.8155
# Epoch 310/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2330 - accuracy: 0.7903
# Epoch 311/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.7640
# Epoch 312/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2314 - accuracy: 0.8065
# Epoch 313/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2483 - accuracy: 0.8033
# Epoch 314/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2391 - accuracy: 0.8088
# Epoch 315/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2318 - accuracy: 0.7944
# Epoch 316/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2225 - accuracy: 0.7755
# Epoch 317/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.7450
# Epoch 318/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.7860
# Epoch 319/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2393 - accuracy: 0.8178
# Epoch 320/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2446 - accuracy: 0.8020
# Epoch 321/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2352 - accuracy: 0.8301
# Epoch 322/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.8005
# Epoch 323/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.7813
# Epoch 324/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.8292
# Epoch 325/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2270 - accuracy: 0.8276
# Epoch 326/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2287 - accuracy: 0.7834
# Epoch 327/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.7438
# Epoch 328/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.7858
# Epoch 329/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2425 - accuracy: 0.7927
# Epoch 330/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2395 - accuracy: 0.8396
# Epoch 331/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2489 - accuracy: 0.8014
# Epoch 332/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.7748
# Epoch 333/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.7600
# Epoch 334/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.7549
# Epoch 335/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2340 - accuracy: 0.8106
# Epoch 336/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2372 - accuracy: 0.8271
# Epoch 337/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.7378
# Epoch 338/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2444 - accuracy: 0.8148
# Epoch 339/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2243 - accuracy: 0.8016
# Epoch 340/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2327 - accuracy: 0.7771
# Epoch 341/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2314 - accuracy: 0.8108
# Epoch 342/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2255 - accuracy: 0.7896
# Epoch 343/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2416 - accuracy: 0.7972
# Epoch 344/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.8524
# Epoch 345/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.8021
# Epoch 346/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 0.7483
# Epoch 347/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.7991
# Epoch 348/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.8100
# Epoch 349/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2479 - accuracy: 0.8048
# Epoch 350/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2244 - accuracy: 0.8243
# Epoch 351/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2510 - accuracy: 0.8103
# Epoch 352/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2309 - accuracy: 0.7979
# Epoch 353/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2374 - accuracy: 0.7929
# Epoch 354/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2426 - accuracy: 0.8268
# Epoch 355/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2408 - accuracy: 0.7987
# Epoch 356/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.8142
# Epoch 357/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2374 - accuracy: 0.8345
# Epoch 358/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2184 - accuracy: 0.7980
# Epoch 359/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2189 - accuracy: 0.8090
# Epoch 360/2000
# 11/11 [==============================] - 0s 996us/step - loss: 0.2412 - accuracy: 0.8432
# Epoch 361/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2341 - accuracy: 0.7875
# Epoch 362/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2212 - accuracy: 0.7983
# Epoch 363/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.8172
# Epoch 364/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2298 - accuracy: 0.7902
# Epoch 365/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 0.8222
# Epoch 366/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2183 - accuracy: 0.7978
# Epoch 367/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2260 - accuracy: 0.7630
# Epoch 368/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2298 - accuracy: 0.7621
# Epoch 369/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2279 - accuracy: 0.7851
# Epoch 370/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2543 - accuracy: 0.8229
# Epoch 371/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2439 - accuracy: 0.7982
# Epoch 372/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2272 - accuracy: 0.7824
# Epoch 373/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2289 - accuracy: 0.8175
# Epoch 374/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.7998
# Epoch 375/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.8047
# Epoch 376/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.8596
# Epoch 377/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.8033
# Epoch 378/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.7787
# Epoch 379/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2163 - accuracy: 0.7885
# Epoch 380/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2552 - accuracy: 0.7756
# Epoch 381/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2437 - accuracy: 0.8213
# Epoch 382/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2469 - accuracy: 0.8302
# Epoch 383/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.7795
# Epoch 384/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2374 - accuracy: 0.7317
# Epoch 385/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.8205
# Epoch 386/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.8412
# Epoch 387/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2192 - accuracy: 0.7635
# Epoch 388/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2361 - accuracy: 0.7594
# Epoch 389/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2295 - accuracy: 0.8262
# Epoch 390/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2279 - accuracy: 0.8033
# Epoch 391/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2076 - accuracy: 0.7641
# Epoch 392/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2405 - accuracy: 0.8220
# Epoch 393/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2183 - accuracy: 0.7722
# Epoch 394/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2538 - accuracy: 0.7847
# Epoch 395/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2339 - accuracy: 0.8385
# Epoch 396/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2216 - accuracy: 0.8407
# Epoch 397/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.8908
# Epoch 398/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.7396
# Epoch 399/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.7837
# Epoch 400/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.8525
# Epoch 401/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2279 - accuracy: 0.8584
# Epoch 402/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2283 - accuracy: 0.8281
# Epoch 403/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2143 - accuracy: 0.7974
# Epoch 404/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2293 - accuracy: 0.8690
# Epoch 405/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2264 - accuracy: 0.8029
# Epoch 406/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2193 - accuracy: 0.8141
# Epoch 407/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2309 - accuracy: 0.8296
# Epoch 408/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2317 - accuracy: 0.7947
# Epoch 409/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2281 - accuracy: 0.7992
# Epoch 410/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2330 - accuracy: 0.8211
# Epoch 411/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.8671
# Epoch 412/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.8355
# Epoch 413/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2443 - accuracy: 0.8122
# Epoch 414/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2426 - accuracy: 0.8306
# Epoch 415/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2422 - accuracy: 0.8328
# Epoch 416/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2354 - accuracy: 0.8128
# Epoch 417/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2244 - accuracy: 0.7884
# Epoch 418/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2175 - accuracy: 0.8040
# Epoch 419/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.7922
# Epoch 420/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.8436
# Epoch 421/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2299 - accuracy: 0.8754
# Epoch 422/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2437 - accuracy: 0.8405
# Epoch 423/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.7672
# Epoch 424/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2383 - accuracy: 0.7978
# Epoch 425/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2554 - accuracy: 0.7621
# Epoch 426/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2353 - accuracy: 0.8594
# Epoch 427/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2213 - accuracy: 0.8538
# Epoch 428/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.8066
# Epoch 429/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2269 - accuracy: 0.8159
# Epoch 430/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2191 - accuracy: 0.8037
# Epoch 431/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.7798
# Epoch 432/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.8029
# Epoch 433/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2321 - accuracy: 0.8550
# Epoch 434/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2192 - accuracy: 0.7835
# Epoch 435/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2443 - accuracy: 0.8576
# Epoch 436/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2216 - accuracy: 0.8270
# Epoch 437/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2284 - accuracy: 0.8269
# Epoch 438/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2387 - accuracy: 0.8208
# Epoch 439/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2425 - accuracy: 0.8279
# Epoch 440/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2256 - accuracy: 0.8150
# Epoch 441/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2293 - accuracy: 0.7897
# Epoch 442/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2290 - accuracy: 0.8233
# Epoch 443/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2289 - accuracy: 0.8498
# Epoch 444/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2368 - accuracy: 0.8202
# Epoch 445/2000
# 11/11 [==============================] - 0s 698us/step - loss: 0.2284 - accuracy: 0.8099
# Epoch 446/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2464 - accuracy: 0.8171
# Epoch 447/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2137 - accuracy: 0.7994
# Epoch 448/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2541 - accuracy: 0.8024
# Epoch 449/2000
# 11/11 [==============================] - 0s 997us/step - loss: 0.2458 - accuracy: 0.7782
# Epoch 450/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2482 - accuracy: 0.7959
# Epoch 451/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.8269
# Epoch 452/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.8535
# Epoch 453/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2163 - accuracy: 0.8090
# Epoch 454/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2517 - accuracy: 0.8345
# Epoch 455/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2395 - accuracy: 0.8183
# Epoch 456/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2254 - accuracy: 0.8373
# Epoch 457/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2326 - accuracy: 0.8432
# Epoch 458/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2375 - accuracy: 0.8138
# Epoch 459/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2251 - accuracy: 0.8067
# Epoch 460/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2344 - accuracy: 0.8419
# Epoch 461/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2232 - accuracy: 0.8329
# Epoch 462/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2107 - accuracy: 0.8361
# Epoch 463/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.8709
# Epoch 464/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2306 - accuracy: 0.8173
# Epoch 465/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2265 - accuracy: 0.8275
# Epoch 466/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2430 - accuracy: 0.8337
# Epoch 467/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.8346
# Epoch 468/2000
# ...
# Epoch 1848/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2330 - accuracy: 0.8443
# Epoch 1849/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.
2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.8769
# Epoch 1991/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2089 - accuracy: 0.8803
# Epoch 1992/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2095 - accuracy: 0.9053
# Epoch 1993/2000
# 11/11 [==============================] - 0s 798us/step - loss: 0.2063 - accuracy: 0.8975
# Epoch 1994/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2152 - accuracy: 0.8671
# Epoch 1995/2000
# 11/11 [==============================] - 0s 897us/step - loss: 0.2220 - accuracy: 0.8915
# Epoch 1996/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2195 - accuracy: 0.8787
# Epoch 1997/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2262 - accuracy: 0.8847
# Epoch 1998/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2311 - accuracy: 0.8963
# Epoch 1999/2000
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.8901
# Epoch 2000/2000
# 11/11 [==============================] - 0s 898us/step - loss: 0.2116 - accuracy: 0.9083

# %%
plt.plot(history['loss'], linewidth=2, label='Train')
#plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %%
train_x_predictions = autoencoder.predict(BigX)
#print(test_data_normalised,test_x_predictions)
#print(TestX)
mse = np.mean(np.power(BigX - train_x_predictions, 2), axis=1)
#print(mse)
#print(type(mse))

# %%
# data to be plotted
x = np.arange(1,len(BigX)+1)
#print(x)
#print(num_examples_test)

# plotting
plt.title("errors")
plt.xlabel("point index- test examples")
plt.ylabel("Reconstruction Error")
plt.plot(x, mse, color ="green")
plt.show()

# %%
# train_x_predictions = autoencoder.predict(BigX)
# #print(test_data_normalised,test_x_predictions)
# #print(BigX)
# mse_train = np.mean(np.power(BigX - train_x_predictions, 2), axis=1)

# %%
# x_train = np.arange(1, num_examples_train+1)
# #print(x)
# #print(num_examples_train)
 
# # plotting
# plt.title("errors")
# plt.xlabel("point index test examples")
# plt.ylabel("Reconstruction Error")
# plt.plot(x_train, mse_train, color ="green")
# plt.show()

# %%
# TestX=loadtxt("stripper_data_13b.txt")
# pprint(TestX)

# %%
Test_dict_1={}
for i in range (1,9):
    temp=loadtxt("./Figure of Eight Testing 1/figure_eight_testing1_"+str(i)+".txt")
    Test_dict_1['Test1'+str(i)+'b']=scaling.transform(temp)
    
Test_dict_2={}
for i in range (1,9):
    temp=loadtxt("./Figure of Eight Testing 2/figure_eight_testing2_"+str(i)+".txt")
    Test_dict_2['Test2'+str(i)+'b']=scaling.transform(temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-99aa8b9aeecf> in <module>
#       7 for i in range (1,9):
#       8     temp=loadtxt("./Figure of Eight Testing 2/figure_eight_testing2_"+str(i)+".txt")
# ----> 9     Test_dict_2['Test2'+str(i)+'b']=scaling.transform(temp)
#      10
#      11
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#    1404         """
#    1405         check_is_fitted(self)
# -> 1406         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#    1407                                 copy=self.copy, estimator=self,
#    1408                                 dtype=FLOAT_DTYPES, reset=False,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     435
#     436         if check_params.get('ensure_2d', True):
# --> 437             self._check_n_features(X, reset=reset)
#     438
#     439         return out
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     363
#     364         if n_features != self.n_features_in_:
# --> 365             raise ValueError(
#     366                 f"X has {n_features} features, but {self.__class__.__name__} "
#     367                 f"is expecting {self.n_features_in_} features as input.")
#
# ValueError: X has 73 features, but RobustScaler is expecting 76 features as input.

# %%
test_predictions_1={}
for i in range(1,9):
    temp=autoencoder.predict(Test_dict_1['Test1'+str(i)+'b'])
    test_predictions_1['Test1'+str(i)+'b']=temp

test_predictions_2={}
for i in range(1,9):
    temp=autoencoder.predict(Test_dict_2['Test2'+str(i)+'b'])
    test_predictions_2['Test2'+str(i)+'b']=temp
    

# test_x_predictions = autoencoder.predict(TestX)

#print(test_data_normalised,test_x_predictions)
#print(TestX)
# mse2 = np.mean(np.power(TestX - test_x_predictions, 2), axis=1)
mse_1={}
for i in range(1,9):
    temp=np.mean(np.power(Test_dict_1['Test1'+str(i)+'b'] - test_predictions_1['Test1'+str(i)+'b'], 2), axis=1)
    mse_1['Test1'+str(i)+'b']=temp
    
mse_2={}
for i in range(1,9):
    temp=np.mean(np.power(Test_dict_2['Test2'+str(i)+'b'] - test_predictions_2['Test2'+str(i)+'b'], 2), axis=1)
    mse_2['Test2'+str(i)+'b']=temp

# %%
# data to be plotted
x_1={}
for i in range(1,9):
    x_1['Test1'+str(i)+'b'] = np.arange(1,len(Test_dict_1['Test1'+str(i)+'b'])+1)
    
x_2={}
for i in range(1,9):
    x_2['Test2'+str(i)+'b'] = np.arange(1,len(Test_dict_2['Test2'+str(i)+'b'])+1)
#print(x)
#print(num_examples_test)

# print("TESTING-1 plots")
# # plotting
# for i in range(1,14):
#     plt.title("errors")
#     plt.xlabel("point index- test examples for set:"+str(i))
#     plt.ylabel("Reconstruction Error")
#     plt.plot(x_1['Test1'+str(i)+'b'], mse_1['Test1'+str(i)+'b'], color ="green")
#     plt.show()
# # data to be plotted
# x_1={}
# for i in range(1,14):
#     x_1['Test1'+str(i)+'b'] = np.arange(1,len(Test_dict_1['Test1'+str(i)+'b'])+1)
    
# x_2={}
# for i in range(1,14):
#     x_2['Test2'+str(i)+'b'] = np.arange(1,len(Test_dict_2['Test2'+str(i)+'b'])+1)
# #print(x)
# #print(num_examples_test)

print("TESTING-1 plots")
# plotting
for i in range(1,9):
    plt.title("errors")
    plt.xlabel("point index- test examples for set:"+str(i))
    plt.ylabel("Reconstruction Error")
    plt.plot(x_1['Test1'+str(i)+'b'], mse_1['Test1'+str(i)+'b'], color ="green")
    plt.show()
    
print("TESTING-2 plots")
# plotting
for i in range(1,9):
    plt.title("errors")
    plt.xlabel("point index- test examples for set:"+str(i))
    plt.ylabel("Reconstruction Error")
    plt.plot(x_2['Test2'+str(i)+'b'], mse_2['Test2'+str(i)+'b'], color ="green")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-9cd00ca09068> in <module>
#       6 x_2={}
#       7 for i in range(1,9):
# ----> 8     x_2['Test2'+str(i)+'b'] = np.arange(1,len(Test_dict_2['Test2'+str(i)+'b'])+1)
#       9 #print(x)
#      10 #print(num_examples_test)
#
# KeyError: 'Test21b'
